# %% [markdown]
# ## Monthly Hotel Booking Analysis Based on Hotel Type

# %%
# melakukan perbandingan jumlah pemesanan hotel berdasarkan nama hotel 
dfg = df.groupby(['hotel','arrival_date_month','arrival_date_year'])['Total_customer'].count().reset_index()
dfg
# Out:
#            hotel arrival_date_month  arrival_date_year  Total_customer
# 0     City Hotel              April               2018            2371
# 1     City Hotel              April               2019            2594
# 2     City Hotel             August               2018            3923
# 3     City Hotel             August               2019            3971
# 4     City Hotel           December               2017            3386
# 5     City Hotel           December               2018            4219
# 6     City Hotel           February               2017            1654
# 7     City Hotel           February               2018            2478
# 8     City Hotel            January               2017            1235
# 9     City Hotel            January               2018            3122
# 10    City Hotel               July               2018            3676
# 11    City Hotel               July               2019            4556
# ...

# %%
# menghitung perbandingan jumlah customer tiap bulan berdasarkan hotel
dfg = dfg.groupby(['hotel','arrival_date_month'])['Total_customer'].mean().reset_index()
dfg
# Out:
#            hotel arrival_date_month  Total_customer
# 0     City Hotel              April     2482.500000
# 1     City Hotel             August     3947.000000
# 2     City Hotel           December     3802.500000
# 3     City Hotel           February     2066.000000
# 4     City Hotel            January     2178.500000
# 5     City Hotel               July     4116.000000
# 6     City Hotel               June     3740.000000
# 7     City Hotel              March     1868.000000
# 8     City Hotel                May     3229.000000
# 9     City Hotel           November     3700.000000
# 10    City Hotel            October     2994.333333
# 11    City Hotel          September     2696.000000
# 12  Resort Hotel              April     1551.500000
# 13  Resort Hotel             August     1522.500000
# 14  Resort Hotel           December     1777.500000
# 15  Resort Hotel           February     1324.000000
# 16  Resort Hotel            January     1218.500000
# ...

# %%
# mengurutkan nama bulan menggunakan fungsi bawaan pandas
dfg = dfg.sort_values('arrival_date_month', key=lambda x: pd.to_datetime(x, format='%B').dt.month)
dfg
# Out:
#            hotel arrival_date_month  Total_customer
# 4     City Hotel            January     2178.500000
# 16  Resort Hotel            January     1218.500000
# 3     City Hotel           February     2066.000000
# 15  Resort Hotel           February     1324.000000
# 7     City Hotel              March     1868.000000
# 19  Resort Hotel              March     1096.500000
# 0     City Hotel              April     2482.500000
# 12  Resort Hotel              April     1551.500000
# 20  Resort Hotel                May     1668.000000
# 8     City Hotel                May     3229.000000
# 6     City Hotel               June     3740.000000
# 18  Resort Hotel               June     1804.500000
# 5     City Hotel               July     4116.000000
# 17  Resort Hotel               July     1779.500000
# 1     City Hotel             August     3947.000000
# 13  Resort Hotel             August     1522.500000
# 11    City Hotel          September     2696.000000
# ...

# %%
dfg = df.groupby(['hotel','arrival_date_month','arrival_date_year'])['Total_customer'].count().reset_index()
dfg = dfg.groupby(['hotel','arrival_date_month'])['Total_customer'].mean().reset_index()
dfg = dfg.sort_values('arrival_date_month', key=lambda x: pd.to_datetime(x, format='%B').dt.month)
dfg
# Out:
#            hotel arrival_date_month  Total_customer
# 4     City Hotel            January     2178.500000
# 16  Resort Hotel            January     1218.500000
# 3     City Hotel           February     2066.000000
# 15  Resort Hotel           February     1324.000000
# 7     City Hotel              March     1868.000000
# 19  Resort Hotel              March     1096.500000
# 0     City Hotel              April     2482.500000
# 12  Resort Hotel              April     1551.500000
# 20  Resort Hotel                May     1668.000000
# 8     City Hotel                May     3229.000000
# 6     City Hotel               June     3740.000000
# 18  Resort Hotel               June     1804.500000
# 5     City Hotel               July     4116.000000
# 17  Resort Hotel               July     1779.500000
# 1     City Hotel             August     3947.000000
# 13  Resort Hotel             August     1522.500000
# 11    City Hotel          September     2696.000000
# ...

# %% [markdown]
# From the existing data, I found that 2017 and 2019 did not have a sufficient number of months, where it can be seen that in 2017 there was only data from September, whereas in 2019 the data was only available in March - October. I assume that the data entered is data from the same year. Between 2017 data or 2019 data, which counts for 1 full year.

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data =dfg, x='arrival_date_month', y='Total_customer',hue ='hotel', palette='Set1' )
plt.title('Total Avarage \nCustomer per Month', weight='bold', fontsize = 15)
plt.ylabel('Avg Customer')
plt.xlabel('Month')

plt.axvline(5, color='green', linestyle='--',ymax = 0.952, ymin=0)
plt.axvline(7, color='green', linestyle='--',ymax = 0.952, ymin=0)
plt.stackplot(np.arange(5,8), [5000], color='limegreen', alpha=0.3)
plt.text( x = 5.75, y= 4750, s= 'High \nSeason', va='center', fontsize =15, color ='green')

plt.axvline(10, color='green', linestyle='--',ymax = 0.952, ymin=0)
plt.axvline(11, color='green', linestyle='--',ymax = 0.952, ymin=0)
plt.stackplot(np.arange(10,12), [5000], color='limegreen', alpha=0.3)
plt.text( x = 10.25, y= 4750, s= 'Peak \nSeason', va='center', fontsize =15, color ='green')

plt.axvline(1, color='red', linestyle='--',ymax = 0.952, ymin=0)
plt.axvline(2, color='red', linestyle='--',ymax = 0.952, ymin=0)
plt.stackplot(np.arange(1,3), [5000], color='red', alpha=0.2)
plt.text( x = 1.25, y= 4750, s= 'Low \nSeason', va='center', fontsize =15, color ='red')

plt.xlim(0,11)
plt.legend(loc='best', fontsize =15)
plt.show()

# %% [markdown]
# From the visualization above, it is illustrated that the average visitor prefers to use a City hotel compared to a Resort Hotel. Then, judging from the holiday distribution, there are 3 phases where there are Low Season, High Season, and lastly Peak Season. This is reflected in the higher level of visitors in High Season where in Indonesia that month is the period of school holidays, religious holidays such as going home and many other types of holidays that month. At the beginning of August there was a decrease where the holiday period was starting to end, but it would be followed by an increase in November and Dec where in those months there were Christmas and New Year Holidays.

# %%
# memfilter data bulan september dan oktober
df_filter = df[(df['arrival_date_month'].isin(['September','October']))]
df_filter
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2017
# 1       Resort Hotel            0        737               2017
# 2       Resort Hotel            0          7               2017
# 3       Resort Hotel            0         13               2017
# 4       Resort Hotel            0         14               2017
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2019
# 119386    City Hotel            0        102               2019
# 119387    City Hotel            0         34               2019
# 119388    City Hotel            0        109               2019
# 119389    City Hotel            0        205               2019
#
#        arrival_date_month  arrival_date_week_number  \
# 0               September                        27
# 1               September                        27
# ...

# %%
# melakukan groupby berdasarkan kolom yang sudah di filter
df_filter.groupby(['is_canceled','arrival_date_month']).size().reset_index(name='count')
# Out:
#    is_canceled arrival_date_month  count
# 0            0            October   8638
# 1            0          September   7919
# 2            1            October   5239
# 3            1          September   4742

# %% [markdown]
# NOTE: for the month column, if the label encoder has been applied, it cannot be returned to the previous value if the previous data type was an object.

# %%
# membuat kolom baru Durasi menginap dari kolom stays_in_weekend_nights dan kolom stays_in_weekdays_nights
df['Durasi_menginap'] =df['stays_in_weekend_nights'] + df['stays_in_weekdays_nights']

# %%
# membuat visualisasi durasi penginapan 
plt.figure(figsize=(10,5))
sns.kdeplot(df['Durasi_menginap'])
plt.show()

# %%
# Membuat kolom baru status_menginap
df['Status_durasi'] = df['Durasi_menginap'].apply (lambda value: 'A day' if value < 7 else ( 'A week' if value < 14 else ('A month' if value < 30 else 'Several month' )))

# %%
df['Status_durasi'].value_counts()
# Out:
# A day            105478
# A week            12557
# A month            1318
# Several month        37
# Name: Status_durasi, dtype: int64

# %%
# melakukan pengelompokan berdasarkan rata-rata durasi menginap 
df.groupby(['is_canceled','hotel']). agg({'Durasi_menginap': 'mean'})
# Out:
#                           Durasi_menginap
# is_canceled hotel
# 0           City Hotel           2.923618
#             Resort Hotel         4.142892
# 1           City Hotel           3.054287
#             Resort Hotel         4.775580

# %% [markdown]
# From the data generated, it can be concluded that the longest duration of stay is at resort hotels, but the number of durations that cancel lodging is also quite high requiring further analysis.

# %%
#membuat tabel baru untuk mengelompokan kolom durasi
df_durasi = df[['hotel','Durasi_menginap','Status_durasi','is_canceled']]
df_durasi
# Out:
#                hotel  Durasi_menginap Status_durasi  is_canceled
# 0       Resort Hotel                0         A day            0
# 1       Resort Hotel                0         A day            0
# 2       Resort Hotel                1         A day            0
# 3       Resort Hotel                1         A day            0
# 4       Resort Hotel                2         A day            0
# ...              ...              ...           ...          ...
# 119385    City Hotel                7        A week            0
# 119386    City Hotel                7        A week            0
# 119387    City Hotel                7        A week            0
# 119388    City Hotel                7        A week            0
# 119389    City Hotel                9        A week            0
#
# [119390 rows x 4 columns]

# %%
# perbandingan jumlah pemesanan hotel yang dibatalkan terhadap durasi menginap untuk setiap jenis hotel
df_durasi_1 = df_durasi[df_durasi['is_canceled']==1].groupby(['hotel','Status_durasi'])['is_canceled'].count().reset_index()
df_durasi_1
# Out:
#           hotel  Status_durasi  is_canceled
# 0    City Hotel          A day        31618
# 1    City Hotel        A month          179
# 2    City Hotel         A week         1295
# 3    City Hotel  Several month           10
# 4  Resort Hotel          A day         7758
# 5  Resort Hotel        A month          305
# 6  Resort Hotel         A week         3053
# 7  Resort Hotel  Several month            6

# %%
# menambahkan kolom ratio durasi 
df_durasi_1['Ratio_duration'] = df_durasi_1['is_canceled']/44224*100
df_durasi_1
# Out:
#           hotel  Status_durasi  is_canceled  Ratio_duration
# 0    City Hotel          A day        31618       71.495116
# 1    City Hotel        A month          179        0.404758
# 2    City Hotel         A week         1295        2.928274
# 3    City Hotel  Several month           10        0.022612
# 4  Resort Hotel          A day         7758       17.542511
# 5  Resort Hotel        A month          305        0.689671
# 6  Resort Hotel         A week         3053        6.903491
# 7  Resort Hotel  Several month            6        0.013567

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x='Status_durasi', y='Ratio_duration', hue='hotel', data=df_durasi_1, palette='viridis')

plt.xlabel('Stay Duration', fontsize=11)
plt.ylabel('Cancellation Rate(%)', fontsize=11)

sns.despine()
plt.tight_layout()

# Menambahkan label pada setiap bar

plt.bar_label(ax.containers[1], fmt='%.2f%%')
plt.bar_label(ax.containers[0], fmt='%.2f%%')
plt.title('Analysis of Stay Duration on \nHotel Bookings Cancellation Rates', weight='bold', fontsize = 15)
plt.show()

# %% [markdown]
# For Stay duration analysis of canceled hotel bookings, for visitors who stay in the A day category or less than one week, they cancel more hotel orders, this requires further analysis of the causes. Possible temporarily there is a lack of hotel service levels, high prices, flexibility of reservations or indeed because of the destination.

# %%
# melihat distribusi dari kolom Lead time(jangka waktu antara pemesanan dan kedatangan customer)
plt.figure(figsize=(15,5))
sns.distplot(df['lead_time'])
plt.show()
# Out:
# F:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# membuat kolom baru dari kolom lead_time
df['lead_time_group'] = df['lead_time'].apply (lambda value: '1 hour' if value < 60 else ( '2 hour' if value < 120  else ('3 hour' if value < 180 else 'for hours' )))

# %%
df['is_canceled'].value_counts()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
df_lead = df[['hotel','is_canceled','lead_time','lead_time_group']].reset_index()
df_lead
# Out:
#          index         hotel  is_canceled  lead_time lead_time_group
# 0            0  Resort Hotel            0        342       for hours
# 1            1  Resort Hotel            0        737       for hours
# 2            2  Resort Hotel            0          7          1 hour
# 3            3  Resort Hotel            0         13          1 hour
# 4            4  Resort Hotel            0         14          1 hour
# ...        ...           ...          ...        ...             ...
# 119385  119385    City Hotel            0         23          1 hour
# 119386  119386    City Hotel            0        102          2 hour
# 119387  119387    City Hotel            0         34          1 hour
# 119388  119388    City Hotel            0        109          2 hour
# 119389  119389    City Hotel            0        205       for hours
#
# [119390 rows x 5 columns]

# %%
df_lead_time = df_lead[df_lead['is_canceled']==1] .groupby(['hotel','lead_time_group'])['is_canceled'].count().reset_index()
df_lead_time
# Out:
#           hotel lead_time_group  is_canceled
# 0    City Hotel          1 hour         9697
# 1    City Hotel          2 hour         7202
# 2    City Hotel          3 hour         5259
# 3    City Hotel       for hours        10944
# 4  Resort Hotel          1 hour         3493
# 5  Resort Hotel          2 hour         2468
# 6  Resort Hotel          3 hour         1917
# 7  Resort Hotel       for hours         3244

# %%
# perbandingan jumlah pemesanan hotel yang dibatalkan terhadap lead time untuk setiap jenis hotel
df_lead_time['Ratio_lead_cancel'] = df_lead_time['is_canceled']/44224*100
df_lead_time
# Out:
#           hotel lead_time_group  is_canceled  Ratio_lead_cancel
# 0    City Hotel          1 hour         9697          21.927008
# 1    City Hotel          2 hour         7202          16.285275
# 2    City Hotel          3 hour         5259          11.891733
# 3    City Hotel       for hours        10944          24.746744
# 4  Resort Hotel          1 hour         3493           7.898426
# 5  Resort Hotel          2 hour         2468           5.580680
# 6  Resort Hotel          3 hour         1917           4.334750
# 7  Resort Hotel       for hours         3244           7.335384

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x='lead_time_group', y='Ratio_lead_cancel', hue='hotel', data=df_lead_time, palette='viridis')

plt.xlabel('Lead Time', fontsize=11)
plt.ylabel('Cancellation Rate(%)', fontsize=11)

sns.despine()
plt.tight_layout()

# Menambahkan label pada setiap bar

plt.bar_label(ax.containers[1], fmt='%.2f%%')
plt.bar_label(ax.containers[0], fmt='%.2f%%')
plt.title('Analysis of Stay Lead Time on \nHotel Bookings Cancellation Rates', weight='bold', fontsize = 15)
plt.show()

# %% [markdown]
# For the analysis of the order-to-check-out period (lead_time) for cancellations, it shows a high increase in bookings with durations of 1 hour and above for the whole. There needs to be a new policy to determine the right decision for lead_time duration. To avoid canceling hotel bookings. For temporary assumptions the causes of cancellations with lead_time above 1 hour are:
# - Marketing strategy
# - Room Availability Planning
